/s eta 0:00:00
# Collecting opentelemetry-sdk<3,>=1.9.0
#   Downloading opentelemetry_sdk-1.27.0-py3-none-any.whl (110 kB)
#      ---------------------------------------- 0.0/110.5 kB ? eta -:--:--
#      ---------- ---------------------------- 30.7/110.5 kB 1.3 MB/s eta 0:00:01
#      ---------- ---------------------------- 30.7/110.5 kB 1.3 MB/s eta 0:00:01
#      ------------------------ ------------ 71.7/110.5 kB 491.5 kB/s eta 0:00:01
#      ------------------------------------ 110.5/110.5 kB 711.1 kB/s eta 0:00:00
# Requirement already satisfied: cachetools<6,>=5.0.0 in c:\users\debjy\anaconda3\lib\site-packages (from mlflow-skinny==2.16.2->mlflow) (5.3.1)
# Collecting databricks-sdk<1,>=0.20.0
#   Downloading databricks_sdk-0.34.0-py3-none-any.whl (565 kB)
#      ---------------------------------------- 0.0/565.6 kB ? eta -:--:--
#      ------ ------------------------------- 102.4/565.6 kB 3.0 MB/s eta 0:00:01
#      --------- ---------------------------- 143.4/565.6 kB 2.8 MB/s eta 0:00:01
#      --------- ---------------------------- 143.4/565.6 kB 2.8 MB/s eta 0:00:01
#      ------------------- ------------------ 286.7/565.6 kB 1.6 MB/s eta 0:00:01
#      --------------------- ---------------- 317.4/565.6 kB 1.6 MB/s eta 0:00:01
#      ------------------------ ------------- 368.6/565.6 kB 1.3 MB/s eta 0:00:01
#      ---------------------------------- --- 512.0/565.6 kB 1.6 MB/s eta 0:00:01
#      -------------------------------------  553.0/565.6 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------  553.0/565.6 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------- 565.6/565.6 kB 1.3 MB/s eta 0:00:00
# Collecting gitpython<4,>=3.1.9
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ---------------------------------------- 0.0/207.3 kB ? eta -:--:--
#      ----- ---------------------------------- 30.7/207.3 kB ? eta -:--:--
#      ----- ---------------------------------- 30.7/207.3 kB ? eta -:--:--
#      ----- ---------------------------------- 30.7/207.3 kB ? eta -:--:--
#      ------------ ------------------------ 71.7/207.3 kB 435.7 kB/s eta 0:00:01
#      ------------ ------------------------ 71.7/207.3 kB 435.7 kB/s eta 0:00:01
#      -----------------------------------  204.8/207.3 kB 731.4 kB/s eta 0:00:01
#      ------------------------------------ 207.3/207.3 kB 698.9 kB/s eta 0:00:00
# Requirement already satisfied: click<9,>=7.0 in c:\users\debjy\anaconda3\lib\site-packages (from mlflow-skinny==2.16.2->mlflow) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in c:\users\debjy\anaconda3\lib\site-packages (from mlflow-skinny==2.16.2->mlflow) (2.2.1)
# Requirement already satisfied: protobuf<6,>=3.12.0 in c:\users\debjy\anaconda3\lib\site-packages (from mlflow-skinny==2.16.2->mlflow) (5.27.2)
# Requirement already satisfied: importlib-metadata!=4.7.0,<9,>=3.7.0 in c:\users\debjy\anaconda3\lib\site-packages (from mlflow-skinny==2.16.2->mlflow) (6.0.0)
# Collecting sqlparse<1,>=0.4.0
#   Downloading sqlparse-0.5.1-py3-none-any.whl (44 kB)
#      ---------------------------------------- 0.0/44.2 kB ? eta -:--:--
#      ---------------------------------------- 44.2/44.2 kB 2.1 MB/s eta 0:00:00
# Collecting opentelemetry-api<3,>=1.9.0
#   Downloading opentelemetry_api-1.27.0-py3-none-any.whl (63 kB)
#      ---------------------------------------- 0.0/64.0 kB ? eta -:--:--
#      ---------------------------------------- 64.0/64.0 kB ? eta 0:00:00
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\debjy\anaconda3\lib\site-packages (from flask) (2.0.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\debjy\anaconda3\lib\site-packages (from flask) (2.2.3)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\debjy\anaconda3\lib\site-packages (from streamlit) (5.3.0)
# Collecting blinker<2,>=1.0.0
#   Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\debjy\anaconda3\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\debjy\anaconda3\lib\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: watchdog<6,>=2.1.5 in c:\users\debjy\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Collecting pydeck<1,>=0.8.0b4
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#      ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#      - -------------------------------------- 0.2/6.9 MB 13.4 MB/s eta 0:00:01
#      - -------------------------------------- 0.2/6.9 MB 13.4 MB/s eta 0:00:01
#      - -------------------------------------- 0.2/6.9 MB 2.0 MB/s eta 0:00:04
#      -- ------------------------------------- 0.3/6.9 MB 2.4 MB/s eta 0:00:03
# ...
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\debjy\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\debjy\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\debjy\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\debjy\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\debjy\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.0.5)
# Collecting wirerope>=0.4.7
#   Downloading wirerope-0.4.7-py2.py3-none-any.whl (9.0 kB)
# Collecting importlib-metadata!=4.7.0,<9,>=3.7.0
#   Downloading importlib_metadata-8.4.0-py3-none-any.whl (26 kB)
# Collecting opentelemetry-exporter-otlp-proto-http==1.27.0
#   Downloading opentelemetry_exporter_otlp_proto_http-1.27.0-py3-none-any.whl (17 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc==1.27.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in c:\users\debjy\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.15.0->apache-airflow) (1.64.1)
# Collecting opentelemetry-proto==1.27.0
#   Downloading opentelemetry_proto-1.27.0-py3-none-any.whl (52 kB)
#      ---------------------------------------- 0.0/52.5 kB ? eta -:--:--
#      ---------------------------------------- 52.5/52.5 kB 2.8 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp-proto-common==1.27.0
#   Downloading opentelemetry_exporter_otlp_proto_common-1.27.0-py3-none-any.whl (17 kB)
# Collecting googleapis-common-protos~=1.52
#   Downloading googleapis_common_protos-1.65.0-py2.py3-none-any.whl (220 kB)
#      ---------------------------------------- 0.0/220.9 kB ? eta -:--:--
#      ------------ -------------------------- 71.7/220.9 kB 3.8 MB/s eta 0:00:01
#      --------------------- ---------------- 122.9/220.9 kB 1.8 MB/s eta 0:00:01
#      -------------------------------------- 220.9/220.9 kB 1.7 MB/s eta 0:00:00
# Collecting protobuf<6,>=3.12.0
#   Downloading protobuf-4.25.5-cp39-cp39-win_amd64.whl (413 kB)
#      ---------------------------------------- 0.0/413.4 kB ? eta -:--:--
#      ---------- --------------------------- 112.6/413.4 kB 3.3 MB/s eta 0:00:01
#      ------------------------ ------------- 266.2/413.4 kB 2.7 MB/s eta 0:00:01
#      ------------------------------------ - 399.4/413.4 kB 3.1 MB/s eta 0:00:01
#      -------------------------------------- 413.4/413.4 kB 2.9 MB/s eta 0:00:00
# Collecting time-machine>=2.6.0
#   Downloading time_machine-2.16.0-cp39-cp39-win_amd64.whl (19 kB)
# Requirement already satisfied: setuptools>=62.4.0 in c:\users\debjy\anaconda3\lib\site-packages (from python-daemon>=3.0.0->apache-airflow) (67.8.0)
# Requirement already satisfied: docutils in c:\users\debjy\anaconda3\lib\site-packages (from python-daemon>=3.0.0->apache-airflow) (0.18.1)
# Requirement already satisfied: six>=1.5 in c:\users\debjy\anaconda3\lib\site-packages (from python-dateutil>=2.7.0->apache-airflow) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\debjy\anaconda3\lib\site-packages (from python-slugify>=5.0->apache-airflow) (1.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\debjy\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\debjy\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (1.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\debjy\anaconda3\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (2.0.1)
# Collecting more-itertools>=9.0.0
#   Downloading more_itertools-10.5.0-py3-none-any.whl (60 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 3.2 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.10.9-cp39-cp39-win_amd64.whl (382 kB)
#      ---------------------------------------- 0.0/382.2 kB ? eta -:--:--
#      -------------- ----------------------- 143.4/382.2 kB 4.3 MB/s eta 0:00:01
#      --------------------------- ---------- 276.5/382.2 kB 3.4 MB/s eta 0:00:01
#      -------------------------------------- 382.2/382.2 kB 3.4 MB/s eta 0:00:00
# Collecting aiohappyeyeballs>=2.3.0
#   Downloading aiohappyeyeballs-2.4.3-py3-none-any.whl (14 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.14.0-cp39-cp39-win_amd64.whl (84 kB)
#      ---------------------------------------- 0.0/84.1 kB ? eta -:--:--
#      -------------------------------------- - 81.9/84.1 kB 4.5 MB/s eta 0:00:01
#      -------------------------------------- - 81.9/84.1 kB 4.5 MB/s eta 0:00:01
#      -------------------------------------- 84.1/84.1 kB 314.3 kB/s eta 0:00:00
# Requirement already satisfied: pycparser in c:\users\debjy\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=41.0.0->apache-airflow) (2.21)
# Requirement already satisfied: google-auth~=2.0 in c:\users\debjy\anaconda3\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.16.2->mlflow) (2.20.0)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Collecting opentelemetry-semantic-conventions==0.48b0
#   Downloading opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl (149 kB)
#      ---------------------------------------- 0.0/149.7 kB ? eta -:--:--
#      -------------------------------------- 149.7/149.7 kB 4.4 MB/s eta 0:00:00
# Collecting propcache>=0.2.0
#   Downloading propcache-0.2.0-cp39-cp39-win_amd64.whl (45 kB)
#      ---------------------------------------- 0.0/45.6 kB ? eta -:--:--
#      ----------------------------------- ---- 41.0/45.6 kB 2.0 MB/s eta 0:00:01
#      ---------------------------------------- 45.6/45.6 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\debjy\anaconda3\lib\site-packages (from email-validator>=1.0.5->flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (2.6.1)
# Requirement already satisfied: Babel>=2.3 in c:\users\debjy\anaconda3\lib\site-packages (from Flask-Babel<3,>=1->flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (2.11.0)
# Collecting limits>=3.13
#   Downloading limits-3.13.0-py3-none-any.whl (45 kB)
#      ---------------------------------------- 0.0/45.5 kB ? eta -:--:--
#      ---------------------------------------- 45.5/45.5 kB 2.2 MB/s eta 0:00:00
# Collecting ordered-set<5,>4
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\debjy\anaconda3\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.16.2->mlflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\debjy\anaconda3\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.16.2->mlflow) (4.9)
# Collecting urllib3>=1.26.0
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#      ---------------------------------------- 0.0/144.2 kB ? eta -:--:--
#      ------------------------ -------------- 92.2/144.2 kB 5.5 MB/s eta 0:00:01
#      ------------------------ -------------- 92.2/144.2 kB 5.5 MB/s eta 0:00:01
#      ---------------------------- ------- 112.6/144.2 kB 939.4 kB/s eta 0:00:01
#      ------------------------------------ 144.2/144.2 kB 957.0 kB/s eta 0:00:00
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\debjy\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.16.2->mlflow) (0.4.8)
# Building wheels for collected packages: python-nvd3, unicodecsv
#   Building wheel for python-nvd3 (setup.py): started
#   Building wheel for python-nvd3 (setup.py): finished with status 'done'
#   Created wheel for python-nvd3: filename=python_nvd3-0.16.0-py3-none-any.whl size=37616 sha256=666fadef1b80ff095eb90094058abdd60adbc0d8d0aa21b40f93256b549aac2e
#   Stored in directory: c:\users\debjy\appdata\local\pip\cache\wheels\b8\e9\9b\1a774c6415c517c2f823c0dfdb61a833d178d85facc657c009
#   Building wheel for unicodecsv (setup.py): started
#   Building wheel for unicodecsv (setup.py): finished with status 'done'
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-py3-none-any.whl size=10759 sha256=b99f220a3e930aa4ba461d265811e11e9417d278608e12f126702a31ab8c6959
#   Stored in directory: c:\users\debjy\appdata\local\pip\cache\wheels\d8\c8\27\b237d3378d5c9ed25c2c63d9af1b3d5ccb99934f3dd030de87
# Successfully built python-nvd3 unicodecsv
# Installing collected packages: unicodecsv, lockfile, cron-descriptor, aniso8601, zipp, WTForms, wirerope, waitress, urllib3, universal-pathlib, uc-micro-py, sqlparse, smmap, setproctitle, rpds-py, rfc3339-validator, python-daemon, protobuf, propcache, prison, pluggy, ordered-set, more-itertools, marshmallow, Mako, gunicorn, graphql-core, google-re2, deprecated, configupdater, colorlog, cachelib, blinker, attrs, asgiref, argcomplete, apispec, aiohappyeyeballs, yarl, time-machine, sqlalchemy-utils, sqlalchemy-jsonfield, referencing, python-nvd3, pydeck, opentelemetry-proto, methodtools, mdit-py-plugins, marshmallow-sqlalchemy, marshmallow-oneofschema, linkify-it-py, importlib-metadata, graphql-relay, googleapis-common-protos, gitdb, cryptography, croniter, clickclick, alembic, rich-argparse, pendulum, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, limits, jsonschema-specifications, graphene, gitpython, docker, databricks-sdk, aiohttp, opentelemetry-semantic-conventions, jsonschema, flask-wtf, Flask-SQLAlchemy, flask-session, flask-login, Flask-Limiter, Flask-JWT-Extended, flask-caching, Flask-Babel, opentelemetry-sdk, flask-appbuilder, connexion, streamlit, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, mlflow-skinny, opentelemetry-exporter-otlp, mlflow, apache-airflow-providers-common-sql, apache-airflow-providers-sqlite, apache-airflow-providers-smtp, apache-airflow-providers-imap, apache-airflow-providers-http, apache-airflow-providers-ftp, apache-airflow-providers-fab, apache-airflow-providers-common-io, apache-airflow-providers-common-compat, apache-airflow
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.11.0
#     Uninstalling zipp-3.11.0:
#       Successfully uninstalled zipp-3.11.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.2
#     Uninstalling urllib3-2.2.2:
#       Successfully uninstalled urllib3-2.2.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.27.2
#     Uninstalling protobuf-5.27.2:
#       Successfully uninstalled protobuf-5.27.2
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 1.0.0
#     Uninstalling pluggy-1.0.0:
#       Successfully uninstalled pluggy-1.0.0
#   Attempting uninstall: more-itertools
#     Found existing installation: more-itertools 8.12.0
#     Uninstalling more-itertools-8.12.0:
#       Successfully uninstalled more-itertools-8.12.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.1.0
#     Uninstalling attrs-22.1.0:
#       Successfully uninstalled attrs-22.1.0
#   Attempting uninstall: yarl
#     Found existing installation: yarl 1.8.1
#     Uninstalling yarl-1.8.1:
#       Successfully uninstalled yarl-1.8.1
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.0.0
#     Uninstalling importlib-metadata-6.0.0:
#       Successfully uninstalled importlib-metadata-6.0.0
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 39.0.1
#     Uninstalling cryptography-39.0.1:
#       Successfully uninstalled cryptography-39.0.1
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.8.3
#     Uninstalling aiohttp-3.8.3:
#       Successfully uninstalled aiohttp-3.8.3
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.17.3
#     Uninstalling jsonschema-4.17.3:
#       Successfully uninstalled jsonschema-4.17.3
# Successfully installed Flask-Babel-2.0.0 Flask-JWT-Extended-4.6.0 Flask-Limiter-3.8.0 Flask-SQLAlchemy-2.5.1 Mako-1.3.5 WTForms-3.1.2 aiohappyeyeballs-2.4.3 aiohttp-3.10.9 alembic-1.13.3 aniso8601-9.0.1 apache-airflow-2.10.2 apache-airflow-providers-common-compat-1.2.0 apache-airflow-providers-common-io-1.4.1 apache-airflow-providers-common-sql-1.17.1 apache-airflow-providers-fab-1.4.0 apache-airflow-providers-ftp-3.11.1 apache-airflow-providers-http-4.13.1 apache-airflow-providers-imap-3.7.0 apache-airflow-providers-smtp-1.8.0 apache-airflow-providers-sqlite-3.9.0 apispec-6.6.1 argcomplete-3.5.1 asgiref-3.8.1 attrs-24.2.0 blinker-1.8.2 cachelib-0.9.0 clickclick-20.10.2 colorlog-6.8.2 configupdater-3.2 connexion-2.14.2 cron-descriptor-1.4.5 croniter-3.0.3 cryptography-43.0.1 databricks-sdk-0.34.0 deprecated-1.2.14 docker-7.1.0 flask-appbuilder-4.5.0 flask-caching-2.3.0 flask-login-0.6.3 flask-session-0.5.0 flask-wtf-1.2.1 gitdb-4.0.11 gitpython-3.1.43 google-re2-1.1.20240702 googleapis-common-protos-1.65.0 graphene-3.3 graphql-core-3.2.4 graphql-relay-3.2.0 gunicorn-23.0.0 importlib-metadata-8.4.0 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 limits-3.13.0 linkify-it-py-2.0.3 lockfile-0.12.2 marshmallow-3.22.0 marshmallow-oneofschema-3.1.1 marshmallow-sqlalchemy-0.28.2 mdit-py-plugins-0.4.2 methodtools-0.4.7 mlflow-2.16.2 mlflow-skinny-2.16.2 more-itertools-10.5.0 opentelemetry-api-1.27.0 opentelemetry-exporter-otlp-1.27.0 opentelemetry-exporter-otlp-proto-common-1.27.0 opentelemetry-exporter-otlp-proto-grpc-1.27.0 opentelemetry-exporter-otlp-proto-http-1.27.0 opentelemetry-proto-1.27.0 opentelemetry-sdk-1.27.0 opentelemetry-semantic-conventions-0.48b0 ordered-set-4.1.0 pendulum-3.0.0 pluggy-1.5.0 prison-0.2.1 propcache-0.2.0 protobuf-4.25.5 pydeck-0.9.1 python-daemon-3.0.1 python-nvd3-0.16.0 referencing-0.35.1 rfc3339-validator-0.1.4 rich-argparse-1.5.2 rpds-py-0.20.0 setproctitle-1.3.3 smmap-5.0.1 sqlalchemy-jsonfield-1.0.2 sqlalchemy-utils-0.41.2 sqlparse-0.5.1 streamlit-1.39.0 time-machine-2.16.0 uc-micro-py-1.0.3 unicodecsv-0.14.1 universal-pathlib-0.2.5 urllib3-1.26.20 waitress-3.0.0 wirerope-0.4.7 yarl-1.14.0 zipp-3.20.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.41 requires requests_mock, which is not installed.
# tensorflow 2.10.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.25.5 which is incompatible.
# tensorflow-intel 2.12.0 requires keras<2.13,>=2.12.0, but you have keras 2.10.0 which is incompatible.
# tensorflow-intel 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.24.3 which is incompatible.
# tensorflow-intel 2.12.0 requires tensorboard<2.13,>=2.12, but you have tensorboard 2.10.1 which is incompatible.
# tensorflow-intel 2.12.0 requires tensorflow-estimator<2.13,>=2.12.0, but you have tensorflow-estimator 2.10.0 which is incompatible.
# tensorboard 2.10.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.25.5 which is incompatible.
# s3fs 2023.4.0 requires fsspec==2023.4.0, but you have fsspec 2024.6.1 which is incompatible.
# python-lsp-black 1.2.1 requires black>=22.3.0, but you have black 0.0 which is incompatible.
# pyopenssl 23.0.0 requires cryptography<40,>=38.0.0, but you have cryptography 43.0.1 which is incompatible.
# grpcio-tools 1.64.1 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.5 which is incompatible.
# gradio 4.37.2 requires urllib3~=2.0, but you have urllib3 1.26.20 which is incompatible.
# conda-repo-cli 1.0.41 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.41 requires nbformat==5.4.0, but you have nbformat 5.7.0 which is incompatible.
# conda-repo-cli 1.0.41 requires requests==2.28.1, but you have requests 2.32.3 which is incompatible.

# %%
# %%writefile finetune.py

import mlflow
import torch
from transformers import Trainer, TrainingArguments, AutoModelForSequenceClassification, AutoTokenizer
from datasets import load_dataset

# Load dataset and model
dataset = load_dataset('yelp_review_full')
model_name = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=5)

# Tokenize the data
def tokenize_function(examples):
    return tokenizer(examples["text"], padding="max_length", truncation=True)

tokenized_datasets = dataset.map(tokenize_function, batched=True)

# Fine-tuning settings
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    weight_decay=0.01,
    logging_dir='./logs',
)

# MLflow tracking
mlflow.set_experiment("LLM_Finetuning_Experiment")

# Trainer and training function
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets['train'],
    eval_dataset=tokenized_datasets['test'],
)

with mlflow.start_run():
    trainer.train()
    mlflow.log_metric("eval_accuracy", trainer.evaluate()["eval_accuracy"])
# Out:
# Writing finetune.py

# %%
# %%writefile airflow_dag.py

from airflow import DAG
from airflow.operators.python_operator import PythonOperator
from datetime import datetime
from transformers import Trainer, TrainingArguments, AutoModelForSequenceClassification, AutoTokenizer
from datasets import load_dataset
import mlflow

# Default args for Airflow
default_args = {
    'owner': 'airflow',
    'start_date': datetime(2024, 1, 1),
    'retries': 1
}

dag = DAG('text_processing_pipeline', default_args=default_args, schedule_interval='@daily')

# Tokenize function
def tokenize_data():
    dataset = load_dataset('yelp_review_full')
    tokenizer = AutoTokenizer.from_pretrained('distilbert-base-uncased')
    
    def tokenize_function(examples):
        return tokenizer(examples['text'], padding="max_length", truncation=True)
    
    tokenized_datasets = dataset.map(tokenize_function, batched=True)
    tokenized_datasets.save_to_disk('/tmp/tokenized_data')

# Fine-tune LLM
def fine_tune_model():
    dataset = load_from_disk('/tmp/tokenized_data')
    model = AutoModelForSequenceClassification.from_pretrained('distilbert-base-uncased', num_labels=5)
    
    training_args = TrainingArguments(
        output_dir="./results",
        evaluation_strategy="epoch",
        per_device_train_batch_size=8,
        num_train_epochs=3,
        weight_decay=0.01,
    )

    mlflow.set_experiment("LLM_Finetuning_Airflow")
    with mlflow.start_run():
        trainer = Trainer(
            model=model,
            args=training_args,
            train_dataset=dataset['train'],
            eval_dataset=dataset['test']
        )
        trainer.train()
        mlflow.log_param("epochs", 3)
        mlflow.log_metric("eval_accuracy", trainer.evaluate()["eval_accuracy"])

# Define Airflow tasks
tokenize_task = PythonOperator(
    task_id='tokenize_task',
    python_callable=tokenize_data,
    dag=dag
)

fine_tune_task = PythonOperator(
    task_id='fine_tune_task',
    python_callable=fine_tune_model,
    dag=dag
)

# Set task dependencies
tokenize_task >> fine_tune_task
# Out:
# Writing airflow_dag.py

# %%
# %%writefile app.py

from flask import Flask, jsonify
from transformers import pipeline

app = Flask(__name__)

# Load the fine-tuned model
model = pipeline("text-classification", model="./results")

@app.route("/predict", methods=["POST"])
def predict():
    data = request.get_json(force=True)
    text = data["text"]
    prediction = model(text)
    return jsonify(prediction)

@app.route("/metrics", methods=["GET"])
def get_metrics():
    client = mlflow.tracking.MlflowClient()
    experiment = client.get_experiment_by_name("LLM_Finetuning_Experiment")
    runs = client.search_runs(experiment.experiment_id)
    metrics = [{"run_id": run.info.run_id, "accuracy": run.data.metrics['eval_accuracy']} for run in runs]
    return jsonify(metrics)

if __name__ == "__main__":
    app.run(host="0.0.0.0", port=5001)
# Out:
# Overwriting app.py

# %%
# %%writefile Dockerfile
#
# # Base image
# FROM python:3.9
#
# # Set environment variables
# ENV AIRFLOW_HOME=/usr/local/airflow
#
# # Install dependencies
# RUN apt-get update && apt-get install -y \
#     python3-pip \
#     && pip3 install --upgrade pip \
#     && pip3 install apache-airflow \
#                    mlflow \
#                    flask \
#                    transformers \
#                    datasets \
#                    torch
#
# # Copy the necessary files
# COPY finetune.py /usr/local/app/finetune.py
# COPY airflow_dag.py /usr/local/airflow/dags/airflow_dag.py
# COPY app.py /usr/local/app/app.py
#
# # Set working directory
# WORKDIR /usr/local/app
#
# # Expose ports for Flask (5000) and Airflow (8080)
# EXPOSE 5001 8081
# RUN airflow db init
# # Command to start Flask and Airflow
# CMD flask run --host=0.0.0.0 --port=5001 & \
#     airflow webserver --port 8081
# Out:
# Overwriting Dockerfile

# %%
pip install apache-airflow==2.10.2
# Out:
# Requirement already satisfied: apache-airflow==2.10.2 in c:\users\debjy\anaconda3\lib\site-packages (2.10.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: apache-airflow-providers-http in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (4.13.1)
# Requirement already satisfied: universal-pathlib!=0.2.4,>=0.2.2 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (0.2.5)
# Requirement already satisfied: packaging>=23.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (23.0)
# Requirement already satisfied: marshmallow-oneofschema>=2.0.1 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (3.1.1)
# Requirement already satisfied: argcomplete>=1.10 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (3.5.1)
# Requirement already satisfied: flask-caching>=2.0.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (2.3.0)
# Requirement already satisfied: alembic<2.0,>=1.13.1 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (1.13.3)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (2.8.2)
# Requirement already satisfied: lazy-object-proxy>=1.2.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (1.6.0)
# Requirement already satisfied: python-nvd3>=0.15.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (0.16.0)
# Requirement already satisfied: asgiref>=2.3.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (3.8.1)
# Requirement already satisfied: markupsafe>=1.1.1 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (2.1.1)
# Requirement already satisfied: colorlog>=6.8.2 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (6.8.2)
# Requirement already satisfied: methodtools>=0.4.7 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (0.4.7)
# Requirement already satisfied: jinja2>=3.0.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (3.1.2)
# Requirement already satisfied: importlib_metadata>=6.5 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (8.4.0)
# Requirement already satisfied: cryptography>=41.0.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (43.0.1)
# Requirement already satisfied: apache-airflow-providers-common-io in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (1.4.1)
# Requirement already satisfied: pendulum<4.0,>=2.1.2 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (3.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (0.10.3)
# Requirement already satisfied: rich-argparse>=1.0.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (1.5.2)
# Requirement already satisfied: python-daemon>=3.0.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (3.0.1)
# Requirement already satisfied: python-slugify>=5.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (5.0.2)
# Requirement already satisfied: setproctitle>=1.3.3 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (1.3.3)
# Requirement already satisfied: apache-airflow-providers-fab>=1.0.2 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (1.4.0)
# Requirement already satisfied: attrs>=22.1.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (24.2.0)
# Requirement already satisfied: mdit-py-plugins>=0.3.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (0.4.2)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (4.23.0)
# Requirement already satisfied: lockfile>=0.12.2 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (0.12.2)
# Requirement already satisfied: pyjwt>=2.0.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (2.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (2.3.0)
# Requirement already satisfied: sqlalchemy-jsonfield>=1.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (1.0.2)
# Requirement already satisfied: dill>=0.2.2 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (0.3.6)
# Requirement already satisfied: configupdater>=3.1.1 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (3.2)
# Requirement already satisfied: flask<2.3,>=2.2.1 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (2.2.2)
# Requirement already satisfied: apache-airflow-providers-common-sql in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (1.17.1)
# Requirement already satisfied: requests-toolbelt>=0.4.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (0.9.1)
# Requirement already satisfied: flask-session<0.6,>=0.4.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (0.5.0)
# Requirement already satisfied: opentelemetry-exporter-otlp>=1.15.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (1.27.0)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (1.8.2)
# Requirement already satisfied: requests<3,>=2.27.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (2.32.3)
# Requirement already satisfied: opentelemetry-api>=1.15.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (1.27.0)
# Requirement already satisfied: pygments>=2.0.1 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (2.15.1)
# Requirement already satisfied: rich>=12.4.4 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (13.7.1)
# Requirement already satisfied: linkify-it-py>=2.0.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (2.0.3)
# Requirement already satisfied: tabulate>=0.7.5 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (0.8.10)
# Requirement already satisfied: unicodecsv>=0.14.1 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (0.14.1)
# Requirement already satisfied: werkzeug<3,>=2.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (2.2.3)
# Requirement already satisfied: apache-airflow-providers-common-compat in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (1.2.0)
# Requirement already satisfied: croniter>=2.0.2 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (3.0.3)
# Requirement already satisfied: apache-airflow-providers-smtp in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (1.8.0)
# Requirement already satisfied: apache-airflow-providers-ftp in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (3.11.1)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (23.0.0)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (2.0.1)
# Requirement already satisfied: apache-airflow-providers-imap in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (3.7.0)
# Requirement already satisfied: pluggy>=1.5.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (1.5.0)
# Requirement already satisfied: connexion[flask]<3.0,>=2.14.2 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (2.14.2)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (0.27.0)
# Requirement already satisfied: markdown-it-py>=2.1.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (3.0.0)
# Requirement already satisfied: apache-airflow-providers-sqlite in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (3.9.0)
# Requirement already satisfied: flask-wtf>=1.1.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (1.2.1)
# Requirement already satisfied: fsspec>=2023.10.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (2024.6.1)
# Requirement already satisfied: rfc3339-validator>=0.1.4 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (0.1.4)
# Requirement already satisfied: sqlalchemy<2.0,>=1.4.36 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (1.4.39)
# Requirement already satisfied: tenacity!=8.2.0,>=8.0.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (8.2.2)
# Requirement already satisfied: cron-descriptor>=1.2.24 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (1.4.5)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (1.2.14)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (5.9.0)
# Requirement already satisfied: google-re2>=1.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow==2.10.2) (1.1.20240702)
# Requirement already satisfied: typing-extensions>=4 in c:\users\debjy\anaconda3\lib\site-packages (from alembic<2.0,>=1.13.1->apache-airflow==2.10.2) (4.12.2)
# Requirement already satisfied: Mako in c:\users\debjy\anaconda3\lib\site-packages (from alembic<2.0,>=1.13.1->apache-airflow==2.10.2) (1.3.5)
# Requirement already satisfied: flask-appbuilder==4.5.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow-providers-fab>=1.0.2->apache-airflow==2.10.2) (4.5.0)
# Requirement already satisfied: jmespath>=0.7.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow-providers-fab>=1.0.2->apache-airflow==2.10.2) (0.10.0)
# Requirement already satisfied: flask-login>=0.6.2 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow-providers-fab>=1.0.2->apache-airflow==2.10.2) (0.6.3)
# Requirement already satisfied: Flask-Babel<3,>=1 in c:\users\debjy\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow==2.10.2) (2.0.0)
# Requirement already satisfied: Flask-Limiter<4,>3 in c:\users\debjy\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow==2.10.2) (3.8.0)
# Requirement already satisfied: prison<1.0.0,>=0.2.1 in c:\users\debjy\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow==2.10.2) (0.2.1)
# Requirement already satisfied: Flask-JWT-Extended<5.0.0,>=4.0.0 in c:\users\debjy\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow==2.10.2) (4.6.0)
# Requirement already satisfied: marshmallow<4,>=3.18.0 in c:\users\debjy\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow==2.10.2) (3.22.0)
# Requirement already satisfied: Flask-SQLAlchemy<3,>=2.4 in c:\users\debjy\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow==2.10.2) (2.5.1)
# Requirement already satisfied: colorama<1,>=0.3.9 in c:\users\debjy\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow==2.10.2) (0.4.6)
# Requirement already satisfied: email-validator>=1.0.5 in c:\users\debjy\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow==2.10.2) (2.2.0)
# Requirement already satisfied: apispec[yaml]<7,>=6.0.0 in c:\users\debjy\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow==2.10.2) (6.6.1)
# Requirement already satisfied: WTForms<4 in c:\users\debjy\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow==2.10.2) (3.1.2)
# Requirement already satisfied: sqlalchemy-utils<1,>=0.32.21 in c:\users\debjy\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow==2.10.2) (0.41.2)
# Requirement already satisfied: marshmallow-sqlalchemy<0.29.0,>=0.22.0 in c:\users\debjy\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow==2.10.2) (0.28.2)
# Requirement already satisfied: click<9,>=8 in c:\users\debjy\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow==2.10.2) (8.1.7)
# Requirement already satisfied: inflection<0.6,>=0.3.1 in c:\users\debjy\anaconda3\lib\site-packages (from connexion[flask]<3.0,>=2.14.2->apache-airflow==2.10.2) (0.5.1)
# Requirement already satisfied: clickclick<21,>=1.2 in c:\users\debjy\anaconda3\lib\site-packages (from connexion[flask]<3.0,>=2.14.2->apache-airflow==2.10.2) (20.10.2)
# Requirement already satisfied: PyYAML<7,>=5.1 in c:\users\debjy\anaconda3\lib\site-packages (from connexion[flask]<3.0,>=2.14.2->apache-airflow==2.10.2) (6.0)
# Requirement already satisfied: pytz>2021.1 in c:\users\debjy\anaconda3\lib\site-packages (from croniter>=2.0.2->apache-airflow==2.10.2) (2022.7)
# Requirement already satisfied: cffi>=1.12 in c:\users\debjy\anaconda3\lib\site-packages (from cryptography>=41.0.0->apache-airflow==2.10.2) (1.15.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\debjy\anaconda3\lib\site-packages (from deprecated>=1.2.13->apache-airflow==2.10.2) (1.14.1)
# Requirement already satisfied: cachelib<0.10.0,>=0.9.0 in c:\users\debjy\anaconda3\lib\site-packages (from flask-caching>=2.0.0->apache-airflow==2.10.2) (0.9.0)
# Requirement already satisfied: idna in c:\users\debjy\anaconda3\lib\site-packages (from httpx>=0.25.0->apache-airflow==2.10.2) (3.4)
# Requirement already satisfied: httpcore==1.* in c:\users\debjy\anaconda3\lib\site-packages (from httpx>=0.25.0->apache-airflow==2.10.2) (1.0.5)
# Requirement already satisfied: certifi in c:\users\debjy\anaconda3\lib\site-packages (from httpx>=0.25.0->apache-airflow==2.10.2) (2023.5.7)
# Requirement already satisfied: sniffio in c:\users\debjy\anaconda3\lib\site-packages (from httpx>=0.25.0->apache-airflow==2.10.2) (1.2.0)
# Requirement already satisfied: anyio in c:\users\debjy\anaconda3\lib\site-packages (from httpx>=0.25.0->apache-airflow==2.10.2) (3.5.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\debjy\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->apache-airflow==2.10.2) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\debjy\anaconda3\lib\site-packages (from importlib_metadata>=6.5->apache-airflow==2.10.2) (3.20.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\debjy\anaconda3\lib\site-packages (from jsonschema>=4.18.0->apache-airflow==2.10.2) (2024.10.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\debjy\anaconda3\lib\site-packages (from jsonschema>=4.18.0->apache-airflow==2.10.2) (0.20.0)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\debjy\anaconda3\lib\site-packages (from jsonschema>=4.18.0->apache-airflow==2.10.2) (0.35.1)
# Requirement already satisfied: uc-micro-py in c:\users\debjy\anaconda3\lib\site-packages (from linkify-it-py>=2.0.0->apache-airflow==2.10.2) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\debjy\anaconda3\lib\site-packages (from markdown-it-py>=2.1.0->apache-airflow==2.10.2) (0.1.2)
# Requirement already satisfied: wirerope>=0.4.7 in c:\users\debjy\anaconda3\lib\site-packages (from methodtools>=0.4.7->apache-airflow==2.10.2) (0.4.7)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.27.0 in c:\users\debjy\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp>=1.15.0->apache-airflow==2.10.2) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.27.0 in c:\users\debjy\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp>=1.15.0->apache-airflow==2.10.2) (1.27.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\debjy\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.15.0->apache-airflow==2.10.2) (1.65.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in c:\users\debjy\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.15.0->apache-airflow==2.10.2) (1.64.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in c:\users\debjy\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.15.0->apache-airflow==2.10.2) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in c:\users\debjy\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.15.0->apache-airflow==2.10.2) (1.27.0)
# Requirement already satisfied: opentelemetry-sdk~=1.27.0 in c:\users\debjy\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.15.0->apache-airflow==2.10.2) (1.27.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in c:\users\debjy\anaconda3\lib\site-packages (from opentelemetry-proto==1.27.0->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.15.0->apache-airflow==2.10.2) (4.25.5)
# Requirement already satisfied: time-machine>=2.6.0 in c:\users\debjy\anaconda3\lib\site-packages (from pendulum<4.0,>=2.1.2->apache-airflow==2.10.2) (2.16.0)
# Requirement already satisfied: tzdata>=2020.1 in c:\users\debjy\anaconda3\lib\site-packages (from pendulum<4.0,>=2.1.2->apache-airflow==2.10.2) (2023.3)
# Requirement already satisfied: setuptools>=62.4.0 in c:\users\debjy\anaconda3\lib\site-packages (from python-daemon>=3.0.0->apache-airflow==2.10.2) (67.8.0)
# Requirement already satisfied: docutils in c:\users\debjy\anaconda3\lib\site-packages (from python-daemon>=3.0.0->apache-airflow==2.10.2) (0.18.1)
# Requirement already satisfied: six>=1.5 in c:\users\debjy\anaconda3\lib\site-packages (from python-dateutil>=2.7.0->apache-airflow==2.10.2) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\debjy\anaconda3\lib\site-packages (from python-slugify>=5.0->apache-airflow==2.10.2) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\debjy\anaconda3\lib\site-packages (from requests<3,>=2.27.0->apache-airflow==2.10.2) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\debjy\anaconda3\lib\site-packages (from requests<3,>=2.27.0->apache-airflow==2.10.2) (1.26.20)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\debjy\anaconda3\lib\site-packages (from sqlalchemy<2.0,>=1.4.36->apache-airflow==2.10.2) (2.0.1)
# Requirement already satisfied: more-itertools>=9.0.0 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow-providers-common-sql->apache-airflow==2.10.2) (10.5.0)
# Requirement already satisfied: sqlparse>=0.4.2 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow-providers-common-sql->apache-airflow==2.10.2) (0.5.1)
# Requirement already satisfied: aiohttp>=3.9.2 in c:\users\debjy\anaconda3\lib\site-packages (from apache-airflow-providers-http->apache-airflow==2.10.2) (3.10.9)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\debjy\anaconda3\lib\site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow==2.10.2) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\debjy\anaconda3\lib\site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow==2.10.2) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\debjy\anaconda3\lib\site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow==2.10.2) (1.14.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\debjy\anaconda3\lib\site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow==2.10.2) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\debjy\anaconda3\lib\site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow==2.10.2) (1.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\debjy\anaconda3\lib\site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow==2.10.2) (2.4.3)
# Requirement already satisfied: pycparser in c:\users\debjy\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=41.0.0->apache-airflow==2.10.2) (2.21)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\debjy\anaconda3\lib\site-packages (from email-validator>=1.0.5->flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow==2.10.2) (2.6.1)
# Requirement already satisfied: Babel>=2.3 in c:\users\debjy\anaconda3\lib\site-packages (from Flask-Babel<3,>=1->flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow==2.10.2) (2.11.0)
# Requirement already satisfied: ordered-set<5,>4 in c:\users\debjy\anaconda3\lib\site-packages (from Flask-Limiter<4,>3->flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow==2.10.2) (4.1.0)
# Requirement already satisfied: limits>=3.13 in c:\users\debjy\anaconda3\lib\site-packages (from Flask-Limiter<4,>3->flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow==2.10.2) (3.13.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in c:\users\debjy\anaconda3\lib\site-packages (from opentelemetry-sdk~=1.27.0->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.15.0->apache-airflow==2.10.2) (0.48b0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\debjy\anaconda3\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow==2.10.2) (0.2.0)
# Requirement already satisfied: importlib-resources>=1.3 in c:\users\debjy\anaconda3\lib\site-packages (from limits>=3.13->Flask-Limiter<4,>3->flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow==2.10.2) (5.2.0)

# %%
# %%writefile Dockerfile
# # Base image
# FROM python:3.9
#
# # Set working directory
# WORKDIR /app
#
# # Install dependencies
# RUN apt-get update && apt-get install -y python3-pip && pip3 install --upgrade pip \
#     && pip3 install transformers torch mlflow accelerate flask datasets
#
# # Copy the fine-tuning and API scripts
# COPY finetune.py /app/finetune.py
# COPY app.py /app/app.py
#
# # Expose Flask port
# EXPOSE 5000
#
# # Run the fine-tuning script first, then start Flask
# CMD python3 finetune.py && python3 app.py
# Out:
# Overwriting Dockerfile

# %%
# %%writefile Dockerfile
#
# # Use the official PyTorch image, which already includes PyTorch and CUDA (if needed)
# FROM pytorch/pytorch:1.9.0-cuda10.2-cudnn7-runtime
#
# # Set working directory
# WORKDIR /app
#
# # Install the remaining dependencies
# RUN pip install --upgrade pip \
#     && pip install transformers[torch] accelerate mlflow flask datasets
#
# RUN pip install scikit-learn
# # Copy your fine-tuning and Flask scripts
# COPY finetune.py /app/finetune.py
# COPY app.py /app/app.py
#
# # Expose Flask port
# EXPOSE 5001
#
# # Run the fine-tuning script first, then start Flask
# CMD python3 finetune.py && python3 app.py
# Out:
# Overwriting Dockerfile

# %%
# %%writefile finetune.py

import mlflow
from transformers import Trainer, TrainingArguments, AutoModelForSequenceClassification, AutoTokenizer
from datasets import load_dataset, load_metric

# Load dataset and limit to 100 samples
dataset = load_dataset('yelp_review_full', split='train[:100]')

# Load pre-trained model and tokenizer
model_name = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=5)

# Tokenize dataset
def tokenize_function(examples):
    return tokenizer(examples['text'], padding="max_length", truncation=True)

tokenized_dataset = dataset.map(tokenize_function, batched=True)

# Load accuracy metric
accuracy_metric = load_metric('accuracy')

# Compute accuracy metric
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = logits.argmax(axis=-1)
    return accuracy_metric.compute(predictions=predictions, references=labels)

# Training arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=1,  # Limiting to 1 epoch
    weight_decay=0.01,
    logging_dir='./logs',
)

# Define Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
    eval_dataset=tokenized_dataset,
    compute_metrics=compute_metrics  # Pass the accuracy computation function
)

# Start fine-tuning and log metrics to MLflow
mlflow.set_experiment("fine-tuning-small")
with mlflow.start_run():
    trainer.train()
    metrics = trainer.evaluate()
    mlflow.log_metrics({"accuracy": metrics['accuracy']})  # Logging accuracy metric
    mlflow.log_param("num_samples", 100)

# Save the fine-tuned model
model.save_pretrained('./results')
# Out:
# Overwriting finetune.py

# %%
# !pip install protobuf==3.20.
# Out:
# Requirement already satisfied: protobuf==3.20.* in c:\users\debjy\anaconda3\lib\site-packages (3.20.3)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)

# %%
# %%writefile app.py

from flask import Flask, jsonify, request
from transformers import pipeline
import mlflow

app = Flask(__name__)

# Load the fine-tuned model
model = pipeline("text-classification", model="./results")

@app.route("/predict", methods=["POST"])
def predict():
    data = request.get_json(force=True)
    text = data['text']
    prediction = model(text)
    return jsonify(prediction)

@app.route("/metrics", methods=["GET"])
def get_metrics():
    client = mlflow.tracking.MlflowClient()
    experiment = client.get_experiment_by_name("fine-tuning-small")
    runs = client.search_runs(experiment.experiment_id)
    metrics = [{"run_id": run.info.run_id, "accuracy": run.data.metrics['accuracy']} for run in runs]
    return jsonify(metrics)

if __name__ == "__main__":
    app.run(host="0.0.0.0", port=5001)
# Out:
# Overwriting app.py

# %%
# !python3 -m pip install pip --upgrade
# !pip install pyopenssl --upgrade
# Out:
# Python was not found; run without arguments to install from the Microsoft Store, or disable this shortcut from Settings > Manage App Execution Aliases.
# Requirement already satisfied: pyopenssl in c:\users\debjy\anaconda3\lib\site-packages (23.0.0)
# Collecting pyopenssl
#   Downloading pyOpenSSL-24.2.1-py3-none-any.whl (58 kB)
#      ---------------------------------------- 0.0/58.4 kB ? eta -:--:--
#      ---------------------------------------- 58.4/58.4 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: cryptography<44,>=41.0.5 in c:\users\debjy\anaconda3\lib\site-packages (from pyopenssl) (43.0.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\debjy\anaconda3\lib\site-packages (from cryptography<44,>=41.0.5->pyopenssl) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\debjy\anaconda3\lib\site-packages (from cffi>=1.12->cryptography<44,>=41.0.5->pyopenssl) (2.21)
# Installing collected packages: pyopenssl
#   Attempting uninstall: pyopenssl
#     Found existing installation: pyOpenSSL 23.0.0
#     Uninstalling pyOpenSSL-23.0.0:
#       Successfully uninstalled pyOpenSSL-23.0.0
# Successfully installed pyopenssl-24.2.1
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)

# %%
pip install -U accelerate
# Out:
# Collecting accelerate
#   Using cached accelerate-1.0.0-py3-none-any.whl (330 kB)
# Requirement already satisfied: torch>=1.10.0 in c:\users\debjy\anaconda3\lib\site-packages (from accelerate) (1.12.1)
# Requirement already satisfied: pyyaml in c:\users\debjy\anaconda3\lib\site-packages (from accelerate) (6.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\debjy\anaconda3\lib\site-packages (from accelerate) (23.0)
# Requirement already satisfied: huggingface-hub>=0.21.0 in c:\users\debjy\anaconda3\lib\site-packages (from accelerate) (0.23.4)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\debjy\anaconda3\lib\site-packages (from accelerate) (0.4.5)
# Requirement already satisfied: psutil in c:\users\debjy\anaconda3\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in c:\users
datasets
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.0
#     Uninstalling tqdm-4.65.0:
#       Successfully uninstalled tqdm-4.65.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 11.0.0
#     Uninstalling pyarrow-11.0.0:
#       Successfully uninstalled pyarrow-11.0.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.12.0
#     Uninstalling datasets-2.12.0:
#       Successfully uninstalled datasets-2.12.0
# Successfully installed datasets-3.0.1 pyarrow-17.0.0 tqdm-4.66.5
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 4.37.2 requires urllib3~=2.0, but you have urllib3 1.26.20 which is incompatible.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)

# %%
from transformers import Trainer, TrainingArguments, AutoModelForSequenceClassification, AutoTokenizer

# %%
# !pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#      ---------------------------------------- 0.0/84.0 kB ? eta -:--:--
#      ---------------------------------------- 84.0/84.0 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.7.0 in c:\users\debjy\anaconda3\lib\site-packages (from evaluate) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\debjy\anaconda3\lib\site-packages (from evaluate) (1.24.3)
# Requirement already satisfied: xxhash in c:\users\debjy\anaconda3\lib\site-packages (from evaluate) (2.0.2)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\debjy\anaconda3\lib\site-packages (from evaluate) (4.66.5)
# Requirement already satisfied: datasets>=2.0.0 in c:\users\debjy\anaconda3\lib\site-packages (from evaluate) (3.0.1)
# Requirement already satisfied: dill in c:\users\debjy\anaconda3\lib\site-packages (from evaluate) (0.3.6)
# Requirement already satisfied: pandas in c:\users\debjy\anaconda3\lib\site-packages (from evaluate) (2.0.2)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in c:\users\debjy\anaconda3\lib\site-packages (from evaluate) (2024.6.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\debjy\anaconda3\lib\site-packages (from evaluate) (2.32.3)
# Requirement already satisfied: multiprocess in c:\users\debjy\anaconda3\lib\site-packages (from evaluate) (0.70.14)
# Requirement already satisfied: packaging in c:\users\debjy\anaconda3\lib\site-packages (from evaluate) (23.0)
# Requirement already satisfied: filelock in c:\users\debjy\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (3.12.2)
# Requirement already satisfied: aiohttp in c:\users\debjy\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (3.10.9)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\debjy\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (17.0.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\debjy\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\debjy\anaconda3\lib\site-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\debjy\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (1.26.20)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\debjy\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\debjy\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\debjy\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: colorama in c:\users\debjy\anaconda3\lib\site-packages (from tqdm>=4.62.1->evaluate) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\debjy\anaconda3\lib\site-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\debjy\anaconda3\lib\site-packages (from pandas->evaluate) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\debjy\anaconda3\lib\site-packages (from pandas->evaluate) (2022.7)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\debjy\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\debjy\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.14.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\debjy\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\debjy\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (24.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\debjy\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\debjy\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\debjy\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: six>=1.5 in c:\users\debjy\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\debjy\anaconda3\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets>=2.0.0->evaluate) (0.2.0)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.3
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\debjy\anaconda3\lib\site-packages)

# %%
import mlflow

from datasets import load_dataset
from evaluate import load as load_metric  # Updated import from the `evaluate` library


# Load dataset and limit to 100 samples
dataset = load_dataset('yelp_review_full', split='train[:100]')

# Load pre-trained model and tokenizer
model_name = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=5)

# Tokenize dataset
def tokenize_function(examples):
    return tokenizer(examples['text'], padding="max_length", truncation=True)

tokenized_dataset = dataset.map(tokenize_function, batched=True)

# Load accuracy metric
accuracy_metric = load_metric('accuracy')

# Compute accuracy metric
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = logits.argmax(axis=-1)
    return accuracy_metric.compute(predictions=predictions, references=labels)

# Training arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=1,  # Limiting to 1 epoch
    weight_decay=0.01,
    logging_dir='./logs',
)
# Out:
# C:\Users\debjy\anaconda3\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_projector.bias', 'vocab_layer_norm.bias', 'vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.bias', 'classifier.weight', 'classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
tokenized_dataset
# Out:
# Dataset({
#     features: ['label', 'text', 'input_ids', 'attention_mask'],
#     num_rows: 100
# })

# %%
# Define Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
    eval_dataset=tokenized_dataset,
    compute_metrics=compute_metrics  # Pass the accuracy computation function
)

# Start fine-tuning and log metrics to MLflow
# Out:
# 2024/10/09 11:20:26 INFO mlflow.tracking.fluent: Experiment with name 'fine-tuning-small' does not exist. Creating a new experiment.
# C:\Users\debjy\anaconda3\lib\site-packages\transformers\optimization.py:407: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='3' max='13' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 3/13 09:36 < 1:36:08, 0.00 it/s, Epoch 0.15/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# KeyboardInterrupt

# %%
mlflow.set_experiment("fine-tuning-small")
with mlflow.start_run():
    metrics = trainer.evaluate()
    mlflow.log_metrics({"accuracy": metrics['accuracy']})  # Logging accuracy metric
    mlflow.log_param("num_samples", 100)

# Save the fine-tuned model
model.save_pretrained('./results')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 mlflow.set_experiment("fine-tuning-small")
#       2 with mlflow.start_run():
# ----> 3     trainer.train()
#       4     metrics = trainer.evaluate()
#       5     mlflow.log_metrics({"accuracy": metrics['accuracy']})  # Logging accuracy metric
#
# File ~\anaconda3\lib\site-packages\transformers\trainer.py:1664, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1659     self.model_wrapped = self.model
#    1661 inner_training_loop = find_executable_batch_size(
#    1662     self._inner_training_loop, self._train_batch_size, args.auto_find_batch_size
#    1663 )
# -> 1664 return inner_training_loop(
#    1665     args=args,
#    1666     resume_from_checkpoint=resume_from_checkpoint,
#    1667     trial=trial,
#    1668     ignore_keys_for_eval=ignore_keys_for_eval,
#    1669 )
#
# File ~\anaconda3\lib\site-packages\transformers\trainer.py:1940, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1938         tr_loss_step = self.training_step(model, inputs)
#    1939 else:
# -> 1940     tr_loss_step = self.training_step(model, inputs)
#    1942 if (
#    1943     args.logging_nan_inf_filter
#    1944     and not is_torch_tpu_available()
#    1945     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    1946 ):
#    1947     # if loss is nan or inf simply add the average of previous logged losses
#    1948     tr_loss += tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~\anaconda3\lib\site-packages\transformers\trainer.py:2735, in Trainer.training_step(self, model, inputs)
#    2732     return loss_mb.reduce_mean().detach().to(self.args.device)
#    2734 with self.compute_loss_context_manager():
# -> 2735     loss = self.compute_loss(model, inputs)
#    2737 if self.args.n_gpu > 1:
#    2738     loss = loss.mean()  # mean() to average on multi-gpu parallel training
#
# File ~\anaconda3\lib\site-packages\transformers\trainer.py:2767, in Trainer.compute_loss(self, model, inputs, return_outputs)
#    2765 else:
#    2766     labels = None
# -> 2767 outputs = model(**inputs)
#    2768 # Save past state if it exists
#    2769 # TODO: this needs to be fixed and made cleaner later.
#    2770 if self.args.past_index >= 0:
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:763, in DistilBertForSequenceClassification.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#     755 r"""
#     756 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#     757     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#     758     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#     759     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#     760 """
#     761 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 763 distilbert_output = self.distilbert(
#     764     input_ids=input_ids,
#     765     attention_mask=attention_mask,
#     766     head_mask=head_mask,
#     767     inputs_embeds=inputs_embeds,
#     768     output_attentions=output_attentions,
#     769     output_hidden_states=output_hidden_states,
#     770     return_dict=return_dict,
#     771 )
#     772 hidden_state = distilbert_output[0]  # (bs, seq_len, dim)
#     773 pooled_output = hidden_state[:, 0]  # (bs, dim)
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:583, in DistilBertModel.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     579 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     581 embeddings = self.embeddings(input_ids, inputs_embeds)  # (bs, seq_length, dim)
# --> 583 return self.transformer(
#     584     x=embeddings,
#     585     attn_mask=attention_mask,
#     586     head_mask=head_mask,
#     587     output_attentions=output_attentions,
#     588     output_hidden_states=output_hidden_states,
#     589     return_dict=return_dict,
#     590 )
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:359, in Transformer.forward(self, x, attn_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     356 if output_hidden_states:
#     357     all_hidden_states = all_hidden_states + (hidden_state,)
# --> 359 layer_outputs = layer_module(
#     360     x=hidden_state, attn_mask=attn_mask, head_mask=head_mask[i], output_attentions=output_attentions
#     361 )
#     362 hidden_state = layer_outputs[-1]
#     364 if output_attentions:
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:313, in TransformerBlock.forward(self, x, attn_mask, head_mask, output_attentions)
#     310 sa_output = self.sa_layer_norm(sa_output + x)  # (bs, seq_length, dim)
#     312 # Feed Forward Network
# --> 313 ffn_output = self.ffn(sa_output)  # (bs, seq_length, dim)
#     314 ffn_output: torch.Tensor = self.output_layer_norm(ffn_output + sa_output)  # (bs, seq_length, dim)
#     316 output = (ffn_output,)
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:254, in FFN.forward(self, input)
#     253 def forward(self, input: torch.Tensor) -> torch.Tensor:
# --> 254     return apply_chunking_to_forward(self.ff_chunk, self.chunk_size_feed_forward, self.seq_len_dim, input)
#
# File ~\anaconda3\lib\site-packages\transformers\pytorch_utils.py:236, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     233     # concatenate output at same dimension
#     234     return torch.cat(output_chunks, dim=chunk_dim)
# --> 236 return forward_fn(*input_tensors)
#
# File ~\anaconda3\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:259, in FFN.ff_chunk(self, input)
#     257 x = self.lin1(input)
#     258 x = self.activation(x)
# --> 259 x = self.lin2(x)
#     260 x = self.dropout(x)
#     261 return x
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
metrics = trainer.evaluate()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 metrics = trainer.evaluate()
#
# File ~\anaconda3\lib\site-packages\transformers\trainer.py:3029, in Trainer.evaluate(self, eval_dataset, ignore_keys, metric_key_prefix)
#    3026 start_time = time.time()
#    3028 eval_loop = self.prediction_loop if self.args.use_legacy_prediction_loop else self.evaluation_loop
# -> 3029 output = eval_loop(
#    3030     eval_dataloader,
#    3031     description="Evaluation",
#    3032     # No point gathering the predictions if there are no metrics, otherwise we defer to
#    3033     # self.args.prediction_loss_only
#    3034     prediction_loss_only=True if self.compute_metrics is None else None,
#    3035     ignore_keys=ignore_keys,
#    3036     metric_key_prefix=metric_key_prefix,
#    3037 )
#    3039 total_batch_size = self.args.eval_batch_size * self.args.world_size
#    3040 if f"{metric_key_prefix}_jit_compilation_time" in output.metrics:
#
# File ~\anaconda3\lib\site-packages\transformers\trainer.py:3239, in Trainer.evaluation_loop(self, dataloader, description, prediction_loss_only, ignore_keys, metric_key_prefix)
#    3237     labels = self._nested_gather(labels)
#    3238     labels_host = labels if labels_host is None else nested_concat(labels_host, labels, padding_index=-100)
# -> 3239 self.control = self.callback_handler.on_prediction_step(args, self.state, self.control)
#    3241 # Gather all tensors and put them back on the CPU if we have done enough accumulation steps.
#    3242 if args.eval_accumulation_steps is not None and (step + 1) % args.eval_accumulation_steps == 0:
#
# File ~\anaconda3\lib\site-packages\transformers\trainer_callback.py:393, in CallbackHandler.on_prediction_step(self, args, state, control)
#     392 def on_prediction_step(self, args: TrainingArguments, state: TrainerState, control: TrainerControl):
# --> 393     return self.call_event("on_prediction_step", args, state, control)
#
# File ~\anaconda3\lib\site-packages\transformers\trainer_callback.py:397, in CallbackHandler.call_event(self, event, args, state, control, **kwargs)
#     395 def call_event(self, event, args, state, control, **kwargs):
#     396     for callback in self.callbacks:
# --> 397         result = getattr(callback, event)(
#     398             args,
#     399             state,
#     400             control,
#     401             model=self.model,
#     402             tokenizer=self.tokenizer,
#     403             optimizer=self.optimizer,
#     404             lr_scheduler=self.lr_scheduler,
#     405             train_dataloader=self.train_dataloader,
#     406             eval_dataloader=self.eval_dataloader,
#     407             **kwargs,
#     408         )
#     409         # A Callback can skip the return of `control` if it doesn't change it.
#     410         if result is not None:
#
# File ~\anaconda3\lib\site-packages\transformers\utils\notebook.py:304, in NotebookProgressCallback.on_prediction_step(self, args, state, control, eval_dataloader, **kwargs)
#     302     else:
#     303         self.prediction_bar = NotebookProgressBar(len(eval_dataloader))
# --> 304     self.prediction_bar.update(1)
#     305 else:
#     306     self.prediction_bar.update(self.prediction_bar.value + 1)
#
# File ~\anaconda3\lib\site-packages\transformers\utils\notebook.py:141, in NotebookProgressBar.update(self, value, force_update, comment)
#     139     self.first_calls = self.warmup
#     140     self.wait_for = 1
# --> 141     self.update_bar(value)
#     142 elif value <= self.last_value and not force_update:
#     143     return
#
# File ~\anaconda3\lib\site-packages\transformers\utils\notebook.py:182, in NotebookProgressBar.update_bar(self, value, comment)
#     180     self.label += f", {1/self.average_time_per_item:.2f} it/s"
#     181 self.label += "]" if self.comment is None or len(self.comment) == 0 else f", {self.comment}]"
# --> 182 self.display()
#
# File ~\anaconda3\lib\site-packages\transformers\utils\notebook.py:188, in NotebookProgressBar.display(self)
#     185 self.html_code = html_progress_bar(self.value, self.total, self.prefix, self.label, self.width)
#     186 if self.parent is not None:
#     187     # If this is a child bar, the parent will take care of the display.
# --> 188     self.parent.display()
#     189     return
#     190 if self.output is None:
#
# File ~\anaconda3\lib\site-packages\transformers\utils\notebook.py:217, in NotebookTrainingTracker.display(self)
#     216 def display(self):
# --> 217     self.html_code = html_progress_bar(self.value, self.total, self.prefix, self.label, self.width)
#     218     if self.inner_table is not None:
#     219         self.html_code += text_to_html_table(self.inner_table)
#
# AttributeError: 'NotebookTrainingTracker' object has no attribute 'value'

# %%
metrics

# %%
pip install requests
